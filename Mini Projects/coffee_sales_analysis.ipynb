# %%
import pandas as pd 

ds = pd.read_csv("C:/Users/Affan/Desktop/Desktop Stuff/ML Work Stuff/ML-Work/Datasets/Coffee Shop Sales.csv")

display(ds.head(2))
display(ds.describe())
display(ds.info())
ds.isna().sum()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       01-01-2023         07:06:11                2
# 1               2       01-01-2023         07:08:56                2
#
#    store_id   store_location  product_id  unit_price product_category  \
# 0         5  Lower Manhattan          32         3.0           Coffee
# 1         5  Lower Manhattan          57         3.1              Tea
#
#             product_type            product_detail
# 0  Gourmet brewed coffee               Ethiopia Rg
# 1        Brewed Chai tea  Spicy Eye Opener Chai Lg
#        transaction_id  transaction_qty       store_id     product_id  \
# count   149116.000000    149116.000000  149116.000000  149116.000000
# mean     74737.371872         1.438276       5.342063      47.918607
# std      43153.600016         0.542509       2.074241      17.930020
# min          1.000000         1.000000       3.000000       1.000000
# ...

# %%
display(ds[['product_detail','unit_price']].head(6))
print('-----------------------------------------------------')
display(ds.iloc[[444]])
print('-----------------------------------------------------')
display(ds.loc[(ds['transaction_qty']==8) & (ds['transaction_id']<=68976)].head(2))
# Out:
#                 product_detail  unit_price
# 0                  Ethiopia Rg         3.0
# 1     Spicy Eye Opener Chai Lg         3.1
# 2            Dark chocolate Lg         4.5
# 3  Our Old Time Diner Blend Sm         2.0
# 4     Spicy Eye Opener Chai Lg         3.1
# 5                Oatmeal Scone         3.0
# -----------------------------------------------------
#      transaction_id transaction_date transaction_time  transaction_qty  \
# 444             445       01-01-2023         17:35:26                1
#
#      store_id store_location  product_id  unit_price product_category  \
# 444         3        Astoria          47         3.0              Tea
#
#          product_type         product_detail
# 444  Brewed Green tea  Serenity Green Tea Lg
# -----------------------------------------------------
#       transaction_id transaction_date transaction_time  transaction_qty  \
# 9310            9340       17-01-2023         09:05:20                8
# ...

# %%
display(ds.sort_values("unit_price",ascending=False).head())
display(ds.sort_values("product_detail").head())
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 103464          103718       22-05-2023         08:20:52                1
# 13832            13862       25-01-2023         08:49:41                1
# 73990            74160       23-04-2023         11:23:14                1
# 148573          148914       30-06-2023         10:25:26                1
# 103238          103492       21-05-2023         20:52:55                1
#
#         store_id   store_location  product_id  unit_price product_category  \
# 103464         5  Lower Manhattan           8        45.0     Coffee beans
# 13832          8   Hell's Kitchen           8        45.0     Coffee beans
# 73990          8   Hell's Kitchen           8        45.0     Coffee beans
# 148573         8   Hell's Kitchen           8        45.0     Coffee beans
# 103238         8   Hell's Kitchen           8        45.0     Coffee beans
#
#          product_type product_detail
# ...

# %%
display(ds.loc[ds['unit_price'] > 25])
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 3296              3326       07-01-2023         07:45:15                1
# 3302              3332       07-01-2023         07:50:42                1
# 3408              3438       07-01-2023         09:05:19                1
# 4598              4628       09-01-2023         09:42:16                1
# 5182              5212       10-01-2023         09:20:43                1
# ...                ...              ...              ...              ...
# 145411          145748       27-06-2023         12:12:41                1
# 145618          145955       27-06-2023         15:19:35                1
# 148573          148914       30-06-2023         10:25:26                1
# 148702          149043       30-06-2023         11:18:31                8
# 148784          149125       30-06-2023         13:03:56                1
#
#         store_id   store_location  product_id  unit_price product_category  \
# ...

# %%
# ds['product_detail'].unique()
display(ds.loc[(ds['product_detail'].str.contains('Rg',case=False,na=False)) & (ds["product_type"].str.contains("Organic",case=False,na=False) & (ds['store_id']==8))].head())
display(ds.query('transaction_qty>2 and unit_price<10').head())
# Out:
#      transaction_id transaction_date transaction_time  transaction_qty  \
# 210             211       01-01-2023         12:55:53                2
# 219             220       01-01-2023         13:02:52                1
# 341             342       01-01-2023         15:24:01                1
# 479             480       01-01-2023         18:14:28                2
# 544             545       01-01-2023         19:45:28                1
#
#      store_id  store_location  product_id  unit_price product_category  \
# 210         8  Hell's Kitchen          26         3.0           Coffee
# 219         8  Hell's Kitchen          26         3.0           Coffee
# 341         8  Hell's Kitchen          26         3.0           Coffee
# 479         8  Hell's Kitchen          26         3.0           Coffee
# 544         8  Hell's Kitchen          26         3.0           Coffee
#
#               product_type product_detail
# 210  Organic brewed coffee   Brazilian Rg
# ...
